# %%
import pymongo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
er=np.seterr(divide='ignore',invalid='ignore')
# %matplotlib inline

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
db = myclient.Jcomp

# %%
Con_KL=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"KL":1})))
Rec_KL=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"KL":1})))
Dec_KL=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"KL":1})))

Con_MH=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"MH":1})))
Rec_MH=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"MH":1})))
Dec_MH=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"MH":1})))

Con_GA=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"GA":1})))
Rec_GA=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"GA":1})))
Dec_GA=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"GA":1})))

Con_KA=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"KA":1})))
Rec_KA=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"KA":1})))
Dec_KA=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"KA":1})))

# %%
plt.figure(figsize=(20, 24))
plt.suptitle("Confirmed, Cured, and Death cases daily in four States", fontsize=20)
plt.subplot(2, 2, 1)

plt.plot(Dec_KL)
plt.plot(Rec_KL)
plt.plot(Con_KL)
plt.title("Kerala", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_KL)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 2)
plt.plot(Dec_MH)
plt.plot(Rec_MH)
plt.plot(Con_MH)
plt.title("Maharastra", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_MH)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 3)
plt.plot(Dec_GA)
plt.plot(Rec_GA)
plt.plot(Con_GA)
plt.title("Goa", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_GA)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 4)
plt.plot(Dec_KA)
plt.plot(Rec_KA)
plt.plot(Con_KA)
plt.title("Karnataka", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_KA)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.tight_layout(15)
plt.show()

# %%
Con_UP=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"UP":1})))
Rec_UP=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"UP":1})))
Dec_UP=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"UP":1})))

Con_TN=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"TN":1})))
Rec_TN=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"TN":1})))
Dec_TN=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"TN":1})))

Con_DL=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"DL":1})))
Rec_DL=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"DL":1})))
Dec_DL=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"DL":1})))

Con_AP=pd.DataFrame(list(db.covid_daily.find({"Status":"Confirmed"},{"_id":0,"AP":1})))
Rec_AP=pd.DataFrame(list(db.covid_daily.find({"Status":"Recovered"},{"_id":0,"AP":1})))
Dec_AP=pd.DataFrame(list(db.covid_daily.find({"Status":"Deceased"},{"_id":0,"AP":1})))

# %%
plt.figure(figsize=(20, 24))
plt.suptitle("Confirmed, Cured, and Death cases daily in four States", fontsize=20)
plt.subplot(2, 2, 1)

plt.plot(Dec_UP)
plt.plot(Rec_UP)
plt.plot(Con_UP)
plt.title("Uttar Pradesh", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_UP)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 2)
plt.plot(Dec_TN)
plt.plot(Rec_TN)
plt.plot(Con_TN)
plt.title("Tamil Nadu", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_TN)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 3)
plt.plot(Dec_DL)
plt.plot(Rec_DL)
plt.plot(Con_DL)
plt.title("Delhi", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_DL)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 4)
plt.plot(Dec_AP)
plt.plot(Rec_AP)
plt.plot(Con_AP)
plt.title("Andhra Pradesh", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_AP)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Deceased","Recovered","Confirmed"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.tight_layout(15)
plt.show()

# %%
plt.figure(figsize=(20, 18))
plt.suptitle("State wise comparison of daily COVID cases", fontsize=20)
plt.subplot(2, 2, 1)

plt.plot(Con_KL)
plt.plot(Con_MH)
plt.plot(Con_GA)
plt.plot(Con_KA)
plt.title("Confirmed", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_KL)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Kerala","Maharashra","Goa","Karnataka"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 2)
plt.plot(Rec_KL)
plt.plot(Rec_MH)
plt.plot(Rec_GA)
plt.plot(Rec_KA)
plt.title("Cured", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Rec_KL)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Kerala","Maharashra","Goa","Karnataka"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 3)
plt.plot(Dec_KL)
plt.plot(Dec_MH)
plt.plot(Dec_GA)
plt.plot(Dec_KA)
plt.title("Deaths", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Dec_KL)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Kerala","Maharashra","Goa","Karnataka"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.tight_layout(7)
plt.show()

# %%
plt.figure(figsize=(20, 18))
plt.suptitle("State wise comparison of daily COVID cases", fontsize=20)
plt.subplot(2, 2, 1)

plt.plot(Con_UP)
plt.plot(Con_TN)
plt.plot(Con_DL)
plt.plot(Con_AP)
plt.title("Confirmed", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Con_UP)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Uttar Pradesh","Tamil Nadu","Delhi","Andhra Pradesh"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 2)
plt.plot(Rec_UP)
plt.plot(Rec_TN)
plt.plot(Rec_DL)
plt.plot(Rec_AP)
plt.title("Cured", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Rec_UP)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Uttar Pradesh","Tamil Nadu","Delhi","Andhra Pradesh"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.subplot(2, 2, 3)
plt.plot(Dec_UP)
plt.plot(Dec_TN)
plt.plot(Dec_DL)
plt.plot(Dec_AP)
plt.title("Deaths", fontsize=18)
labels=['03/20','04/20','05/20','06/20','07/20','07/20','08/20','09/20','10/20','11/20','12/20','01/21','02/21','03/21','04/21']
plt.xticks(np.arange(0, len(Dec_UP)+1, 28),labels,rotation='vertical')
plt.xlabel("Date")
plt.ylabel("Cases")
plt.legend(["Uttar Pradesh","Tamil Nadu","Delhi","Andhra Pradesh"],loc=1)
plt.axvspan(23, 84, alpha=0.5, color='red')
plt.axvspan(378, 406, alpha=0.5, color='grey')

plt.tight_layout(7)
plt.show()
